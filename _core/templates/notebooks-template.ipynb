# %% [markdown]
# # {{TOPIC_TITLE}}
#
# 이 노트북은 {{SECTION_PURPOSE}}을 직접 실행하고 검증하는 실습 자료이다.
# 이전 노트북의 변수나 실행 결과를 사용하지 않으며, 이 노트북 단독으로 완전히 실행할 수 있다.
#
# **목표**
# - 첫 번째 목표를 기술한다.
# - 두 번째 목표를 기술한다.
# - 세 번째 목표를 기술한다.

# %% [markdown]
# ## 0. 환경 설정

# %%
# sys.path setup — excluded from jupyter book build
import os
import sys

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

print(f"project_root={PROJECT_ROOT}")

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Replace with the actual imports for this Phase
from src.{{MODULE_PATH}} import {{API_NAME}}

# %% [markdown]
# ## 1. 개요
#
# 이 주제가 필요한 이유와 전체 흐름에서의 위치를 1~2 단락으로 설명한다.
# docs 섹션 1(개요)과 섹션 2(개념)에 대응하는 요약이다.
#
# 핵심 개념은 다음과 같다.
#
# | 개념 | 설명 | 출력 범위 |
# |---|---|---|
# | 개념 1 | 직관적 설명 | 범위 또는 형태 |
# | 개념 2 | 직관적 설명 | 범위 또는 형태 |

# %% [markdown]
# ## 2. {{PRACTICE_TITLE_1}}
#
# 이 실습의 목적과 예상 결과를 먼저 설명한다.
# 입력이 어떤 형태이고, 실행 후 어떤 결과를 확인할 것인지 안내한다.

# %%
# 실습 코드
x = np.array([...])
y = {{API_NAME}}(x)

print(f"x.shape={x.shape}, x.dtype={x.dtype}")
print(f"y.shape={y.shape}, y.dtype={y.dtype}")

# %%
fig, ax = plt.subplots(figsize=(7, 4))
ax.plot(x, y, linewidth=2)
ax.set_title("{{PLOT_TITLE}}")
ax.set_xlabel("input")
ax.set_ylabel("output")
ax.grid(alpha=0.3)
fig.tight_layout()
plt.show()

# %%
assert y.shape == x.shape
assert y.dtype == np.float32
# 추가 검증
print("validation passed")

# %% [markdown]
# ## 3. {{PRACTICE_TITLE_2}}
#
# 두 번째 실습의 목적과 예상 결과를 설명한다.
# Phase 성격에 따라 섹션 수와 제목을 자유롭게 구성한다.

# %%
# 실습 코드

# %%
# 검증
print("validation passed")

# %% [markdown]
# ## 요약
#
# 이 노트북에서 확인한 내용은 다음과 같다.
#
# | 항목 | 특징 | 비고 |
# |---|---|---|
# | `{{API_NAME}}` | 특징 설명 | 출력 범위 또는 형태 |
#
# **핵심 설계 원칙**
# - 첫 번째 설계 원칙을 기술한다.
# - 두 번째 설계 원칙을 기술한다.
